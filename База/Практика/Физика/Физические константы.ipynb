# %% [markdown]
# [← Оглавление базы](../../INDEX.ipynb)

# %% [markdown]
# # Международная система единиц (СИ)
#
# | Физическая величина                    | Обозначение                                         | Значение                  | Единицы                      |
# | -------------------------------------- | --------------------------------------------------- | ------------------------- | ---------------------------- |
# | Постоянная Больцмана                   | $k$                                                 | $1.38065 \times 10^{-23}$ | Дж·К$^{-1}$                  |
# | Элементарный заряд                     | $e$                                                 | $1.60218 \times 10^{-19}$ | Кл                           |
# | Масса электрона                        | $m_e$                                               | $9.10938 \times 10^{-31}$ | кг                           |
# | Масса протона                          | $m_p$                                               | $1.67262 \times 10^{-27}$ | кг                           |
# | Гравитационная постоянная              | $G$                                                 | $6.67430 \times 10^{-11}$ | $\frac{м^3}{кг \cdotс^{2} }$ |
# | Постоянная Планка                      | $h$                                                 | $6.62607 \times 10^{-34}$ | Дж·с                         |
# |                                        | $\hbar = h/2\pi$                                    | $1.05457 \times 10^{-34}$ | Дж·с                         |
# | Скорость света в вакууме               | $c$                                                 | $2.99792 \times 10^{8}$   | м·с$^{-1}$                   |
# | Диэлектрическая проницаемость вакуума  | $\varepsilon_0$                                     | $8.85419 \times 10^{-12}$ | Ф·м$^{-1}$                   |
# | Магнитная проницаемость вакуума        | $\mu_0$                                             | $1.25664 \times 10^{-6}$  | Гн·м$^{-1}$                  |
# | Отношение масс протона и электрона     | $m_p/m_e$                                           | $1.83615 \times 10^{3}$   | —                            |
# | Отношение заряда электрона к массе     | $e/m_e$                                             | $1.75882 \times 10^{11}$  | Кл·кг$^{-1}$                 |
# | Постоянная Ридберга                    | $R_\infty = \dfrac{m_e^4}{8\varepsilon_0^2 c h^3}$  | $1.09737 \times 10^{7}$   | м$^{-1}$                     |
# | Боровский радиус                       | $a_\infty = \dfrac{\varepsilon_0 h^2}{\pi m_e e^2}$ | $5.29177 \times 10^{-11}$ | м                            |
# | Атомное сечение                        | $\pi a_\infty^2$                                    | $8.79736 \times 10^{-21}$ | м$^2$                        |
# | Классический радиус электрона          | $r_e = \dfrac{e^2}{4\pi\varepsilon_0 m_e c^2}$      | $2.81794 \times 10^{-15}$ | м                            |
# | Сечение Томсона                        | $\dfrac{8\pi}{3} r_e^2$                             | $6.65246 \times 10^{-29}$ | м$^2$                        |
# | Комптоновская длина волны электрона    | $\dfrac{h}{m_e c}$                                  | $2.42631 \times 10^{-12}$ | м                            |
# |                                        | $\dfrac{\hbar}{m_e c}$                              | $3.86159 \times 10^{-13}$ | м                            |
# | Постоянная тонкой структуры            | $\alpha = \dfrac{e^2}{2\varepsilon_0 h c}$          | $7.29735 \times 10^{-3}$  | —                            |
# |                                        | $\alpha^{-1}$                                       | $137.036$                 | —                            |
# | Первая радиационная постоянная         | $c_1 = 2\pi h c^2$                                  | $3.74177 \times 10^{-16}$ | Вт·м$^2$                     |
# | Вторая радиационная постоянная         | $c_2 = \dfrac{h c}{k}$                              | $1.43878 \times 10^{-2}$  | м·К                          |
# | Постоянная Стефана–Больцмана           | $\sigma$                                            | $5.67037 \times 10^{-8}$  | $\frac{Вт}{м^2 \cdot K^{4}}$ |
# | Длина волны, соответствующая 1 эВ      | $\lambda_0 = \dfrac{h c}{e}$                        | $1.23984 \times 10^{-6}$  | м                            |
# | Частота, соответствующая 1 эВ          | $\nu_0 = \dfrac{e}{h}$                              | $2.41799 \times 10^{14}$  | Гц                           |
# | Волновое число, соответствующее 1 эВ   | $k_0 = \dfrac{e}{hc}$                               | $8.06554 \times 10^{5}$   | м$^{-1}$                     |
# | Энергия, соответствующая 1 эВ          | $h\nu_0$                                            | $1.60218 \times 10^{-19}$ | Дж                           |
# | Энергия, соответствующая 1 м$^{-1}$    | $hc$                                                | $1.98645 \times 10^{-25}$ | Дж                           |
# | Энергия, соответствующая 1 ридбергу    | $\dfrac{m_e e^3}{8\varepsilon_0^2 h^2}$             | $13.6057$                 | эВ                           |
# | Энергия, соответствующая 1 кельвину    | $\dfrac{k}{e}$                                      | $8.61733 \times 10^{-5}$  | эВ                           |
# | Температура, соответствующая 1 эВ      | $\dfrac{e}{k}$                                      | $1.16045 \times 10^{4}$   | К                            |
# | Число Авогадро                         | $N_A$                                               | $6.02214 \times 10^{23}$  | моль$^{-1}$                  |
# | Постоянная Фарадея                     | $F = N_A e$                                         | $9.64853 \times 10^{4}$   | Кл·моль$^{-1}$               |
# | Газовая постоянная                     | $R = N_A k$                                         | $8.31446$                 | Дж·К$^{-1}$·моль$^{-1}$      |
# | Число Лошмидта (концентрация при Н.У.) | $n_0$                                               | $2.68678 \times 10^{25}$  | м$^{-3}$                     |
# | Атомная единица массы                  | $m_u$                                               | $1.66054 \times 10^{-27}$ | кг                           |
# | Стандартная температура                | $T_0$                                               | $273.15$                  | К                            |
# | Атмосферное давление                   | $p_0 = n_0 k T_0$                                   | $1.01325 \times 10^{5}$   | Па                           |
# | Давление 1 мм рт. ст. (1 торр)         | —                                                   | $1.33322 \times 10^{2}$   | Па                           |
# | Молярный объём при Н.У.                | $V_0 = \dfrac{R T_0}{p_0}$                          | $2.24140 \times 10^{-2}$  | м$^{3}$/моль                 |
# | Молярная масса воздуха                 | $M_{\text{air}}$                                    | $2.89647 \times 10^{-2}$  | кг/моль                      |
# | Калория (cal)                          | —                                                   | $4.184$                   | Дж                           |
# | Ускорение свободного падения           | $g$                                                 | $9.80665$                 | м·с$^{-2}$                   |

# %% [markdown]
# # Сантиметр грамм секунда (СГС)
#
# | Физическая величина                    | Обозначение                                | Значение                  | Единицы                              |
# | -------------------------------------- | ------------------------------------------ | ------------------------- | ------------------------------------ |
# | Постоянная Больцмана                   | $k$                                        | $1.38065 \times 10^{-16}$ | эрг/К                                |
# | Элементарный заряд                     | $e$                                        | $4.80320 \times 10^{-10}$ | стКл                                 |
# | Масса электрона                        | $m_e$                                      | $9.10938 \times 10^{-28}$ | г                                    |
# | Масса протона                          | $m_p$                                      | $1.67262 \times 10^{-24}$ | г                                    |
# | Гравитационная постоянная              | $G$                                        | $6.67430 \times 10^{-8}$  | дин·см$^{2}$/г$^{2}$                 |
# | Постоянная Планка                      | $h$                                        | $6.62607 \times 10^{-27}$ | эрг·с                                |
# |                                        | $\hbar = h/2\pi$                           | $1.05457 \times 10^{-27}$ | эрг·с                                |
# | Скорость света в вакууме               | $c$                                        | $2.99792 \times 10^{10}$  | см/с                                 |
# | Отношение масс протона и электрона     | $m_p/m_e$                                  | $1.83615 \times 10^{3}$   | —                                    |
# | Отношение заряда электрона к массе     | $e/m_e$                                    | $5.27281 \times 10^{17}$  | стКл/г                               |
# | Постоянная Ридберга                    | $R_\infty = \dfrac{2\pi^2 m_e e^4}{c h^3}$ | $1.09737 \times 10^{5}$   | см$^{-1}$                            |
# | Боровский радиус                       | $a_\infty = \dfrac{\hbar^2}{m_e e^2}$      | $5.29177 \times 10^{-9}$  | см                                   |
# | Атомное сечение                        | $\pi a_\infty^2$                           | $8.79736 \times 10^{-17}$ | см$^{2}$                             |
# | Классический радиус электрона          | $r_e = \dfrac{e^2}{m_e c^2}$               | $2.81794 \times 10^{-13}$ | см                                   |
# | Сечение Томсона                        | $\dfrac{8\pi}{3} r_e^2$                    | $6.65246 \times 10^{-25}$ | см$^{2}$                             |
# | Комптоновская длина волны электрона    | $\dfrac{h}{m_e c}$                         | $2.42631 \times 10^{-10}$ | см                                   |
# |                                        | $\dfrac{\hbar}{m_e c}$                     | $3.86159 \times 10^{-11}$ | см                                   |
# | Постоянная тонкой структуры            | $\alpha = \dfrac{e^2}{\hbar c}$            | $7.29735 \times 10^{-3}$  | —                                    |
# |                                        | $\alpha^{-1}$                              | $137.036$                 | —                                    |
# | Первая радиационная постоянная         | $c_1 = 2\pi h c^2$                         | $3.74177 \times 10^{-5}$  | эрг·см$^{2}$/с                       |
# | Вторая радиационная постоянная         | $c_2 = \dfrac{h c}{k}$                     | $1.43878$                 | см·К                                 |
# | Постоянная Стефана–Больцмана           | $\sigma$                                   | $5.67037 \times 10^{-5}$  | $\frac{эрг }{см^2 \cdot с\cdot К^4}$ |
# | Длина волны, соответствующая 1 эВ      | $\lambda_0$                                | $1.23984 \times 10^{-4}$  | см                                   |
# | Частота, соответствующая 1 эВ          | $\nu_0$                                    | $2.41799 \times 10^{14}$  | Гц                                   |
# | Волновое число, соответствующее 1 эВ   | $k_0$                                      | $8.06554 \times 10^{3}$   | см$^{-1}$                            |
# | Энергия, соответствующая 1 эВ          | —                                          | $1.60218 \times 10^{-12}$ | эрг                                  |
# | Энергия, соответствующая 1 см$^{-1}$   | —                                          | $1.98645 \times 10^{-16}$ | эрг                                  |
# | Энергия, соответствующая 1 ридбергу    | —                                          | $13.6057$                 | эВ                                   |
# | Энергия, соответствующая 1 К           | —                                          | $8.61733 \times 10^{-5}$  | эВ                                   |
# | Температура, соответствующая 1 эВ      | —                                          | $1.16045 \times 10^{4}$   | К                                    |
# | Число Авогадро                         | $N_A$                                      | $6.02214 \times 10^{23}$  | моль$^{-1}$                          |
# | Постоянная Фарадея                     | $F = N_A e$                                | $2.89256 \times 10^{14}$  | стКл/моль                            |
# | Газовая постоянная                     | $R = N_A k$                                | $8.31446 \times 10^{7}$   | эрг/(К·моль)                         |
# | Число Лошмидта (концентрация при Н.У.) | $n_0$                                      | $2.68678 \times 10^{19}$  | см$^{-3}$                            |
# | Атомная единица массы                  | $m_u$                                      | $1.66054 \times 10^{-24}$ | г                                    |
# | Стандартная температура                | $T_0$                                      | $273.15$                  | К                                    |
# | Атмосферное давление                   | $p_0 = n_0 k T_0$                          | $1.01325 \times 10^{6}$   | дин/см$^{2}$                         |
# | Давление 1 мм рт. ст. (1 торр)         | —                                          | $1.33322 \times 10^{3}$   | дин/см$^{2}$                         |
# | Молярный объём при Н.У.                | $V_0 = \dfrac{R T_0}{p_0}$                 | $2.24140 \times 10^{4}$   | см$^{3}$/моль                        |
# | Молярная масса воздуха                 | $M_{\text{air}}$                           | $28.9647$                 | г/моль                               |
# | Калория (cal)                          | —                                          | $4.184 \times 10^{7}$     | эрг                                  |
# | Ускорение свободного падения           | $g$                                        | $980.665$                 | см/с$^{2}$                           |
