# %% [markdown]
# [← Оглавление базы](INDEX.ipynb)

# %% [markdown]
# # Буква К

# %% [markdown]
# ## буква о:

# %% [markdown]
# ### -буква н:
#
# - ***Контаминация*** (от лат. смешивание) - загрязнение/привнесение инородных частиц или скрещивание элементов. <a id="block-0e997d"></a>

# %% [markdown]
# # Буква Л

# %% [markdown]
# ## буква е:

# %% [markdown]
# ### -буква г:
#
# - ***Легирование*** - добавление в состав материалов примесей для изменения физических и/или химических свойств основного материала. <a id="block-9025d9"></a>

# %% [markdown]
# # Буква Н

# %% [markdown]
# ## буква у:

# %% [markdown]
# ### -буква т:
#
# - ***Нутация*** -происходящее одновременно с прецессией движение твёрдого тела,
# при котором изменяется угол между осью собственного вращения тела и осью, вокруг которой происходит прецессия; этот угол называется углом H.
#
# <img src="image/Pasted%20image%2020260303131936.png" width="300" alt="Pasted image 20260303131936.png">

# %% [markdown]
# # Буква З

# %% [markdown]
# ## буква е:

# %% [markdown]
# ### -буква р:
#
# - ***Зернистость (источника) (hash mode)***- это неустойчивый режим работы ионного источника, при котором разряд и извлекаемый ионный пучок становится сильно флуктуирующим по току и пространственной структуре. <a id="block-103edc"></a>

# %% [markdown]
# # Буква П

# %% [markdown]
# ## буква р:

# %% [markdown]
# ### -буква е:
#
# - ***Прецессия*** - явление, при котором ось вращения тела меняет своё направление в пространстве:
#
# <img src="image/Gyroscope_precession.gif" width="428" alt="Gyroscope_precession.gif">

# %% [markdown]
# # Буква Р

# %% [markdown]
# ## буква е:

# %% [markdown]
# ### -буква ф:
#
# - ***Рефлексный разряд*** - это стационарный низкодавленный газовый разряд в скрещённых электрическом и магнитном полях $\boldsymbol{B } \perp \boldsymbol{ E}$, в котором магнитное поле резко увеличивает время удержания электронов за счёт их циклотронного движения и отражения от потенциальных барьеров, так что длина их эффективного пробега становится намного больше геометрического размера разрядного промежутка, обеспечивая интенсивную ионизацию газа. <a id="block-8e7e9d"></a>
# - ***Рефлектор*** - это устройство или поверхность предназначенная для собирания/перенаправления света, тепла, радиоволн и другого излучения. <a id="block-03b5d5"></a>

# %% [markdown]
# # Буква С

# %% [markdown]
# ## буква п:

# %% [markdown]
# ### -буква и:
#
# - ***Спиновое эхо*** - то спонтанное возникновение сигнала [ядерного магнитного резонанса](https://ru.wikipedia.org/wiki/%D0%AF%D0%B4%D0%B5%D1%80%D0%BD%D1%8B%D0%B9_%D0%BC%D0%B0%D0%B3%D0%BD%D0%B8%D1%82%D0%BD%D1%8B%D0%B9_%D1%80%D0%B5%D0%B7%D0%BE%D0%BD%D0%B0%D0%BD%D1%81 "Ядерный магнитный резонанс") и [электронного парамагнитного резонанса](https://ru.wikipedia.org/wiki/%D0%AD%D0%BB%D0%B5%D0%BA%D1%82%D1%80%D0%BE%D0%BD%D0%BD%D1%8B%D0%B9_%D0%BF%D0%B0%D1%80%D0%B0%D0%BC%D0%B0%D0%B3%D0%BD%D0%B8%D1%82%D0%BD%D1%8B%D0%B9_%D1%80%D0%B5%D0%B7%D0%BE%D0%BD%D0%B0%D0%BD%D1%81 "Электронный парамагнитный резонанс") через некоторое время после подачи на образец последовательности импульсов радиочастотного поля:
#
# <img src="image/SpinEcho2_GWM.gif" width="655" alt="SpinEcho2_GWM.gif">
#
# В начальный момент времени группа спинов (изображена красными стрелками)
# ориентирована вдоль магнитного поля $H_0$, направленного вертикально (по оси $z$).
#
# Затем с помощью импульса $\pi/2$ поворачиваем спины в горизонтальную ($x$–$y$) плоскость.
#
# Далее будем предполагать, что спины находятся в системе координат, вращающейся
# с частотой $\omega = \gamma H_0$ вокруг оси $z$. В такой системе координат
# в однородном магнитном поле спины покоятся, но из-за локальных неоднородностей
# магнитного поля спины начинают прецессировать с различной скоростью
# и в различных направлениях. Это приводит к затуханию суммарной намагниченности.
#
# Через некоторое время $t$ прикладываем $\pi$-импульс, который разворачивает
# спины в противоположном направлении.
#
# Видим, что за следующие $t$ секунд каждый спин повернётся в том же направлении
# на тот же угол, на который он повернулся за предыдущие $t$ секунд. Это значит,
# что через $t$ секунд после разворота $\pi$-импульсом фазы всех спинов совпадут.
#
# Фазы всех спинов совпали.

# %% [markdown]
# # Буква Т

# %% [markdown]
# ## буква е:

# %% [markdown]
# ### -буква р:
#
# - ***Термализованные (электроны)*** - это электроны, которые в результате многократных столкновений потеряли избыточную энергию и пришли к распределению энергий, близкому к тепловому (максвелловскому), соответствующему температуре плазмы. <a id="block-a3d556"></a>

# %% [markdown]
# # Буква Э

# %% [markdown]
# ## буква к:

# %% [markdown]
# ### -буква с:
#
# - ***Экстракционная (решетка)*** -  это электродная система с апертурами, которая формирует электрическое поле для извлечения ионов из плазмы и их ускорения/фокусировки в пучок <a id="block-2aa406"></a>
