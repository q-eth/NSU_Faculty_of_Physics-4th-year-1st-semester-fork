# %% [markdown]
# # Лабораторная 1
#
# <span style="font-size: 20pt;">Исследование свойств ферритового циркулятора.</span>

# %% [markdown]
# ## Выполнение работы:

# %% [markdown]
# 1) Подключение волноводного детектора (рисунок 14)
#
# Параметры генератора высокочастотных колебаний:
#
# - CW Frequency: 9.660 GHz
# - Pulse (Train) Period: 99.999 (100) ms [чувствительность прибора 10 Hz]
# - Pulse 1 Width: 50 ms
#
# Устройство: APSIN2G 100 kHz to 12 GHz

# %% [markdown]
# При CW Power = -4 dBm, значение $ \alpha_0 $ = 5 V (фиксированная величина, к которой будем приводить остальные схемы)

# %% [markdown]
# 2) Данные для матричных элементов:
#
# 2.1) Измерительная линия входит в 1:
#
# - Элемент $ S_{21}  $: $ P_2 =16.62 dBm $ (для проверки снова вернул рисунок 14: -4 dBm снова дал $ \alpha_0 =5 V $  )
# - Элемент $ S_{31}  $: $ P_3 = - 2.78 dBm $
# - Элемент $ S_{11}  $: $ P_2^* =  8.45 dBm$, $ P_1^* = 6.28 dBm $ $ (\min = 3 V) $
#
# 2.2) Измерительная линия входит в 2:
#
# - Элемент $ S_{12}  $: $ P_1 =13.35 dBm $ (детектор в 1)
# - Элемент $ S_{32}  $: $ P_3 = 16.85 dBm $ (детектор в 3)
# - Элемент $ S_{22}  $: $ P_2^* =  10.88 dBm$, $ P_1^* = 5 dBm $ $ (\min = 3 V) $
#
# 2.3) Измерительная линия входит в 3:
#
# - Элемент $ S_{13}  $: $ P_1 = 13.14 dBm $ (детектор в 1)
# - Элемент $ S_{23}  $: $ P_2 = -2.45 dBm $ (детектор в 2)
# - Элемент $ S_{33}  $: $ P_2^* =  8.20 dBm$, $ P_1^* = 6.29 dBm $ $ (\min = 3 V) $

# %% [markdown]
# Итоговая матрица:
#
# $$
# S =
# \begin{pmatrix}
# -18.11 & 17.35 & 17.14 \\
# 20.62 & -9.73 & 1.55 \\
# 1.22 & 20.85 & -19.21
# \end{pmatrix}.
# $$
