# %% [markdown]
# # Лабораторная работа 2
# ## Исследование свойств волноводного направленного ответвителя

# %% [markdown]
# ## 1. Условия измерений

# %% [markdown]
# ## 2. Результаты измерений

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Определяем переходное ослабление. Для этого выставляем максимальное значение на **аттенюаторе** 50 для рисунка случая когда индикатор в B, а генератор в A, записываем значения $\alpha_0 $ . После собираем когда индикатор в С, а генератор в А, и меняя значения **аттенюатора** получаем исходное значение $ \alpha_0 $.

# %% [markdown]
# |Частота генератора| $ \alpha_0 $  | $ m $, дБ|
# |:---|:---|:---|
# |9300|5.8|11.8|
# |9400|5.6|11.4|
# |9500|5.4|10.8|
# |9600|6.3|9.8|
# |9700|4.4|9.7|

# %% [markdown]
# |Частота генератора|Переходное ослабление|
# |:---|:---|
# |9300|38.2|
# |9400|38.6|
# |9500|39.2|
# |9600|40.2|
# |9700|40.3|

# %% [markdown]
# 2. Определяем направленность. Для этого выставляем минимальное значение на аттенюаторе 0 для случая когда индикатор в C, а генератор в B, записываем значение $ \alpha_0 $. После собираем когда индикатор в C, а генератор в А, и меняя значения аттенюатора получаем исходное значение $ \alpha_0 $.

# %% [markdown]
# |Частота генератора| $ \alpha_0 $  | $ m $, дБ|
# |:---|:---|:---|
# |9300|1.8|25.5|
# |9400|3.5|21.5|
# |9500|4.6|18.6|
# |9600|4.8|17.4|
# |9700|4.2|16.9|
